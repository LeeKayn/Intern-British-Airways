# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# import requests
# from bs4 import BeautifulSoup
# import pandas as pd
#
# base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
# pages = 40
# page_size = 100
#
# data = {
#     "text_header": [],
#     "reviews": [],
#     "recommended": [],
#     "type_of_traveller": [],
#     "seat_type": [],
#     "route": [],
#     "date_flown": [],
#     "seat_comfort": [],
#     "cabin_staff_service": [],
#     "food_and_beverages": [],
#     "inflight_entertainment": [],
#     "ground_service": [],
#     "wifi_and_connectivity": [],
#     "value_for_money": []
# }
#
# for i in range(1, pages + 1):
#     print(f"Scraping page {i}")
#
#     url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"
#     response = requests.get(url)
#     content = response.content
#     parsed_content = BeautifulSoup(content, 'html.parser')
#
#     for block in parsed_content.find_all("div", class_="body"):
#         text_header = block.find("h2", class_="text_header").text.strip()
#         data['text_header'].append(text_header)
#
#         review_text = block.find("div", class_="text_content").get_text()
#         data['reviews'].append(review_text)
#
#         type_of_traveller_element = block.find("td", class_="type_of_traveller")
#         data['type_of_traveller'].append(type_of_traveller_element.find_next_sibling("td").get_text() if type_of_traveller_element else "N/A")
#
#         seat_type_element = block.find("td", class_="cabin_flown")
#         data['seat_type'].append(seat_type_element.find_next_sibling("td").get_text() if seat_type_element else "N/A")
#
#         route_element = block.find("td", class_="route")
#         data['route'].append(route_element.find_next_sibling("td").get_text() if route_element else "N/A")
#
#         date_flown_element = block.find("td", class_="date_flown")
#         next_td_element = date_flown_element.find_next("td") if date_flown_element else None
#         data['date_flown'].append(next_td_element.get_text() if next_td_element else "N/A")
#
#         seat_comfort_element = block.find("td", class_="seat_comfort")
#         next_td_element = seat_comfort_element.find_next("td") if seat_comfort_element else None
#         stars = next_td_element.find_all("span", class_="star fill") if next_td_element else None
#         data['seat_comfort'].append(max([int(star.get_text()) for star in stars]) if stars else "N/A")
#
#         cabin_staff_service_element = block.find("td", class_="cabin_staff_service")
#         next_td_element = cabin_staff_service_element.find_next("td") if cabin_staff_service_element else None
#         stars = next_td_element.find_all("span", class_="star fill") if next_td_element else None
#         data['cabin_staff_service'].append(max([int(star.get_text()) for star in stars]) if stars else "N/A")
#
#         food_and_beverages_element = block.find("td", class_="food_and_beverages")
#         next_td_element = food_and_beverages_element.find_next("td") if food_and_beverages_element else None
#         stars = next_td_element.find_all("span", class_="star fill") if next_td_element else None
#         data['food_and_beverages'].append(max([int(star.get_text()) for star in stars]) if stars else "N/A")
#
#         inflight_entertainment_element = block.find("td", class_="inflight_entertainment")
#         next_td_element = inflight_entertainment_element.find_next("td") if inflight_entertainment_element else None
#         stars = next_td_element.find_all("span", class_="star fill") if next_td_element else None
#         data['inflight_entertainment'].append(max([int(star.get_text()) for star in stars]) if stars else "N/A")
#
#         ground_service_element = block.find("td", class_="ground_service")
#         next_td_element = ground_service_element.find_next("td") if ground_service_element else None
#         stars = next_td_element.find_all("span", class_="star fill") if next_td_element else None
#         data['ground_service'].append(max([int(star.get_text()) for star in stars]) if stars else "N/A")
#
#         wifi_and_connectivity_element = block.find("td", class_="wifi_and_connectivity")
#         next_td_element = wifi_and_connectivity_element.find_next("td") if wifi_and_connectivity_element else None
#         stars = next_td_element.find_all("span", class_="star fill") if next_td_element else None
#         data['wifi_and_connectivity'].append(max([int(star.get_text()) for star in stars]) if stars else "N/A")
#
#         value_for_money_element = block.find("td", class_="value_for_money")
#         stars = value_for_money_element.find_next_sibling("td").find_all("span", class_="star fill")
#         data['value_for_money'].append(max([int(star.get_text()) for star in stars]) if stars else "N/A")
#
#         recommended_element = block.find("td", class_="recommended")
#         data['recommended'].append(recommended_element.find_next_sibling("td").get_text() if recommended_element else "N/A")
#
#     print(f"   ---> {len(data['reviews'])} total reviews")
#
# df = pd.DataFrame(data)
# df.to_csv('airline_reviews.csv', index=False)
# Out:
# Scraping page 1
#    ---> 100 total reviews
# Scraping page 2
#    ---> 200 total reviews
# Scraping page 3
#    ---> 300 total reviews
# Scraping page 4
#    ---> 400 total reviews
# Scraping page 5
#    ---> 500 total reviews
# Scraping page 6
#    ---> 600 total reviews
# Scraping page 7
#    ---> 700 total reviews
# Scraping page 8
#    ---> 800 total reviews
# Scraping page 9
#    ---> 900 total reviews
# Scraping page 10
#    ---> 1000 total reviews
# Scraping page 11
#    ---> 1100 total reviews
# Scraping page 12
#    ---> 1200 total reviews
# Scraping page 13
#    ---> 1300 total reviews
# Scraping page 14
#    ---> 1400 total reviews
# Scraping page 15
#    ---> 1500 total reviews
# Scraping page 16
#    ---> 1600 total reviews
# Scraping page 17
#    ---> 1700 total reviews
# Scraping page 18
#    ---> 1800 total reviews
# Scraping page 19
#    ---> 1900 total reviews
# Scraping page 20
#    ---> 2000 total reviews
# Scraping page 21
#    ---> 2100 total reviews
# ...

# %%
df=pd.read_csv("airline_reviews.csv")
df.head()
# Out:
#                                    text_header  \
# 0                              "Total garbage"
# 1  "arrived at the airport only 1 hour before"
# 2                    "so callous and uncaring"
# 3                         "uncomfy old planes"
# 4        "never fly British Airway ever again"
#
#                                              reviews recommended  \
# 0  Not Verified | I flew with numerous airlines, ...          no
# 1  ✅ Trip Verified |  We were traveling as a fami...          no
# 2  ✅ Trip Verified | Flight at 8.40am from DUB to...          no
# 3  ✅ Trip Verified |  Terrible. I have traveled t...          no
# 4  ✅ Trip Verified |  The customer service is ugl...          no
#
#   type_of_traveller       seat_type                             route  \
# 0      Solo Leisure   Economy Class    Bucharest to Dallas via London
# 1    Family Leisure   Economy Class                 Gatwick to Venice
# 2      Solo Leisure   Economy Class             Dublin to London City
# ...

# %%
df.describe()
# Out:
#        seat_comfort  cabin_staff_service  food_and_beverages  \
# count   3468.000000          3458.000000         3218.000000
# mean       2.893887             3.268363            2.728713
# std        1.362372             1.488259            1.440366
# min        1.000000             1.000000            1.000000
# 25%        2.000000             2.000000            1.000000
# 50%        3.000000             3.000000            3.000000
# 75%        4.000000             5.000000            4.000000
# max        5.000000             5.000000            5.000000
#
#        inflight_entertainment  ground_service  wifi_and_connectivity  \
# count             2491.000000     2733.000000             565.000000
# mean                 2.660377        2.821076               1.930973
# std                  1.400040        1.451700               1.359435
# min                  1.000000        1.000000               1.000000
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Tạo DataFrame df từ tệp "airline_reviews.csv"
df = pd.read_csv("airline_reviews.csv")

# Lấy chỉ mục "mean" từ mô tả thống kê và tạo biểu đồ
means = df.describe().loc['mean']
means.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Variables')
plt.ylabel('Mean')
plt.title('Mean Values of Variables')
plt.xticks(rotation=45)
plt.savefig("mean_values_plot.png")
plt.show()

# %%
df["Verified"] = df["reviews"].apply(lambda x: 1 if "✅ Trip Verified" in x or "✅ Verified Review" in x else 0)
df["comment"] = df["reviews"].str.replace("Not Verified", "").str.replace("✅ Trip Verified |", "").str.replace("✅ Verified Review ", "").str.replace("❎ ", "")
df = df.drop("reviews", axis=1)
columns_order = ["Verified", "comment"] + df.columns[:-2].tolist()
df = df.reindex(columns=columns_order)

# %%
df.head()
# Out:
#    Verified                                            comment  \
# 0         0   | I flew with numerous airlines, but I gotta ...
# 1         1    We were traveling as a family (5 people). Be...
# 2         1   Flight at 8.40am from DUB to LCY cancelled 11...
# 3         1    Terrible. I have traveled twice with them th...
# 4         1    The customer service is ugly. Tried calling ...
#
#                                    text_header recommended type_of_traveller  \
# 0                              "Total garbage"          no      Solo Leisure
# 1  "arrived at the airport only 1 hour before"          no    Family Leisure
# 2                    "so callous and uncaring"          no      Solo Leisure
# 3                         "uncomfy old planes"          no          Business
# 4        "never fly British Airway ever again"          no      Solo Leisure
#
#         seat_type                             route date_flown  seat_comfort  \
# ...

# %%
df["comment"] = df["comment"].str.replace("| ", "")
df.head()
df.to_csv("new_airline_reviews.csv", index=False)

# %%
verification_counts = df["Verified"].value_counts()

# %%
import matplotlib.pyplot as plt

verification_counts = df["Verified"].value_counts()

labels = ["Not Verified", "Verified"]
counts = verification_counts.values
colors = ["red", "green"]
explode = (0, 0.1)

plt.pie(counts, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
plt.title("Verification Distribution")

plt.show()

# %%
df["recommended"] = df["recommended"].replace({"yes": 1, "no": 0})

# %%
import matplotlib.pyplot as plt

recommend_counts = df["recommended"].value_counts()

labels = ["Not Recommended", "Recommended"]
sizes = recommend_counts.values
colors = ["red", "green"]
explode = (0, 0.1)  # Tách phần Recommended

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')  # Đảm bảo hình tròn
plt.title("Recommendation Distribution")
plt.show()

# %%
reviews_df = df[["comment", "recommended"]]

# %%
reviews_df.head()
# Out:
#                                              comment  recommended
# 0   I flew with numerous airlines, but I gotta ad...            0
# 1    We were traveling as a family (5 people). Be...            0
# 2   Flight at 8.40am from DUB to LCY cancelled 11...            0
# 3    Terrible. I have traveled twice with them th...            0
# 4    The customer service is ugly. Tried calling ...            0

# %%
reviews_df = reviews_df.sample(frac = 0.1, replace = False, random_state=42)

# %%
from nltk.corpus import wordnet

def get_wordnet_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

import string
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer

def clean_text(text):
    # lower text
    text = text.lower()
    # tokenize text and remove puncutation
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    # remove words that contain numbers
    text = [word for word in text if not any(c.isdigit() for c in word)]
    # remove stop words
    stop = stopwords.words('english')
    text = [x for x in text if x not in stop]
    # remove empty tokens
    text = [t for t in text if len(t) > 0]
    # pos tag text
    pos_tags = pos_tag(text)
    # lemmatize text
    text = [WordNetLemmatizer().lemmatize(t[0], get_wordnet_pos(t[1])) for t in pos_tags]
    # remove words with only one letter
    text = [t for t in text if len(t) > 1]
    # join all
    text = " ".join(text)
    return(text)

# clean text data
reviews_df["review_clean"] = reviews_df["comment"].apply(lambda x: clean_text(x))

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
reviews_df["sentiments"] = reviews_df["comment"].apply(lambda x: sid.polarity_scores(x))
reviews_df = pd.concat([reviews_df.drop(['sentiments'], axis=1), reviews_df['sentiments'].apply(pd.Series)], axis=1)

# %%
reviews_df["nb_chars"] = reviews_df["comment"].apply(lambda x: len(x))
reviews_df["nb_words"] = reviews_df["comment"].apply(lambda x: len(x.split(" ")))

# %%
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(reviews_df["review_clean"].apply(lambda x: x.split(" ")))]

# train a Doc2Vec model with our text data
model = Doc2Vec(documents, vector_size=5, window=2, min_count=1, workers=4)

# transform each document into a vector data
doc2vec_df = reviews_df["review_clean"].apply(lambda x: model.infer_vector(x.split(" "))).apply(pd.Series)
doc2vec_df.columns = ["doc2vec_vector_" + str(x) for x in doc2vec_df.columns]
reviews_df = pd.concat([reviews_df, doc2vec_df], axis=1)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(min_df = 10)
tfidf_result = tfidf.fit_transform(reviews_df["review_clean"]).toarray()
tfidf_df = pd.DataFrame(tfidf_result, columns = tfidf.get_feature_names_out())
tfidf_df.columns = ["word_" + str(x) for x in tfidf_df.columns]
tfidf_df.index = reviews_df.index
reviews_df = pd.concat([reviews_df, tfidf_df], axis=1)

# %%
reviews_df.head()
# Out:
#                                                 comment  recommended  \
# 457     During the time of Covid-19 it is normal, th...            0
# 1647   Amsterdam to Gatwick was the usual short haul...            0
# 351     I have a flight booked for January 2022, the...            0
# 1667   Malta to Gatwick. My friend arrived at the ch...            0
# 1849   London Heathrow to Delhi return. I thought Ai...            0
#
#                                            review_clean    neg    neu    pos  \
# 457   time normal airline cancel flight i’m ok also ...  0.083  0.868  0.049
# 1647  amsterdam gatwick usual short haul commuter fl...  0.092  0.821  0.087
# 351   flight book january send email begin december ...  0.076  0.911  0.013
# 1667  malta gatwick friend arrive check desk long qu...  0.047  0.849  0.103
# 1849  london heathrow delhi return think air india w...  0.210  0.748  0.042
#
#       compound  nb_chars  nb_words  doc2vec_vector_0  ...  word_within  \
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color = 'white',
        max_words = 200,
        max_font_size = 40,
        scale = 3,
        random_state = 42
    ).generate(str(data))

    fig = plt.figure(1, figsize = (20, 20))
    plt.axis('off')
    if title:
        fig.suptitle(title, fontsize = 20)
        fig.subplots_adjust(top = 2.3)

    plt.imshow(wordcloud)
    plt.show()

# print wordcloud
show_wordcloud(reviews_df["comment"])

# %%
reviews_df[reviews_df["nb_words"] >= 5].sort_values("pos", ascending = False)[["comment", "pos"]].head(10)
# Out:
#                                                 comment    pos
# 2818  BA2204/5 LGW-PUJ-LGW B777-200ER. Both flights ...  0.448
# 511     New York  to London Heathrow. Very good, sta...  0.430
# 3160  AMS-LHR-JNBJNB-LHR-AMS all flights on time ver...  0.421
# 1067    Dubai to London Heathrow. Lovely flight and ...  0.404
# 3362  Flew Sydney - Singapore - London return. Thoro...  0.399
# 314     Outstanding! From the warm, smiling welcome ...  0.387
# 840     Flying premium economy on British Airways fr...  0.328
# 102    BA 242 on the 6/2/23. Boarding was delayed du...  0.318
# 1236   Flew from London Heathrow to Belfast George B...  0.317
# 2312  British Airways return from Glasgow to New Yor...  0.309

# %%
reviews_df[reviews_df["nb_words"] >= 5].sort_values("neg", ascending = False)[["comment", "neg"]].head(10)
# Out:
#                                                 comment    neg
# 144     Disappointing again especially on business. ...  0.297
# 736     London to Nashville. The worst airline Trans...  0.228
# 2464  Shameful service from British Airways travelli...  0.220
# 3129  IAH-LHR B747 which was old but sat upstairs an...  0.219
# 3309  9/8/14 LHR-EWR in WC. Clean aircraft but moder...  0.213
# 58     Lost 3 out of 4 checked bags. Denied wheelcha...  0.213
# 1849   London Heathrow to Delhi return. I thought Ai...  0.210
# 2177   Amsterdam to Hong Kong via London with Britis...  0.208
# 495     Madrid to London. I keep giving BA the benef...  0.208
# 2965  BA085 LHR to YVR 10/03/15. Narrow seats withou...  0.205

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for x in [0, 1]:
    subset = reviews_df[reviews_df['recommended'] == x]

    if x == 0:
        label = "Good reviews"
    else:
        label = "Bad reviews"
    sns.kdeplot(data=subset, x='compound', label=label)

plt.title('Compound Sentiment Distribution')
plt.xlabel('Compound Sentiment')
plt.ylabel('Density')

plt.legend()
plt.savefig("compund.png")
plt.show()

# %%
label = "recommended"
ignore_cols = [label, "comment", "review_clean"]
features = [c for c in reviews_df.columns if c not in ignore_cols]

# split the data into train and test
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(reviews_df[features], reviews_df[label], test_size = 0.20, random_state = 42)

# %%
rf = RandomForestClassifier(n_estimators = 100, random_state = 42)
rf.fit(X_train, y_train)

# show feature importance
feature_importances_df = pd.DataFrame({"feature": features, "importance": rf.feature_importances_}).sort_values("importance", ascending = False)
feature_importances_df.head(20)
# Out:
#               feature  importance
# 2                 pos    0.094126
# 3            compound    0.067538
# 0                 neg    0.062825
# 213     word_friendly    0.023676
# 115  word_comfortable    0.022044
# 6    doc2vec_vector_0    0.019230
# 134         word_crew    0.017974
# 224         word_good    0.017214
# 1                 neu    0.016358
# 182    word_excellent    0.015684
# 4            nb_chars    0.012699
# 8    doc2vec_vector_2    0.011944
# 7    doc2vec_vector_1    0.010107
# 5            nb_words    0.009963
# 272          word_lhr    0.009783
# 69         word_board    0.009487
# 9    doc2vec_vector_3    0.008897
# 156        word_drink    0.007998
# 465         word_time    0.007020
# 339          word_pay    0.006796

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
import matplotlib.pyplot as plt

y_pred = [x[1] for x in rf.predict_proba(X_test)]
fpr, tpr, thresholds = roc_curve(y_test, y_pred, pos_label = 1)

roc_auc = auc(fpr, tpr)

plt.figure(1, figsize = (15, 10))
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.savefig("ROC.png")
plt.show()

# %%
from sklearn.metrics import average_precision_score, precision_recall_curve
from funcsigs import signature

average_precision = average_precision_score(y_test, y_pred)

precision, recall, _ = precision_recall_curve(y_test, y_pred)

# In matplotlib < 1.5, plt.fill_between does not have a 'step' argument
step_kwargs = ({'step': 'post'}
               if 'step' in signature(plt.fill_between).parameters
               else {})

plt.figure(1, figsize = (15, 10))
plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, alpha=0.2, color='b', **step_kwargs)

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(average_precision))
plt.savefig("PR Curve.png")
